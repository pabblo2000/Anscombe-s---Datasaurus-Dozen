# %%
import numpy as np
import pandas as pd
from IPython.display import display, HTML
import plotly.express as px

# %%
data = pd.read_csv('datasaurus.csv')
display(data)
print("Hay", data["dataset"].nunique(), "datasets diferentes: ", data["dataset"].unique())
# Out:
#          dataset          x          y
# 0           dino  55.384600  97.179500
# 1           dino  51.538500  96.025600
# 2           dino  46.153800  94.487200
# 3           dino  42.820500  91.410300
# 4           dino  40.769200  88.333300
# ...          ...        ...        ...
# 1841  wide_lines  33.674442  26.090490
# 1842  wide_lines  75.627255  37.128752
# 1843  wide_lines  40.610125  89.136240
# 1844  wide_lines  39.114366  96.481751
# 1845  wide_lines  34.583829  89.588902
#
# [1846 rows x 3 columns]
# Hay 13 datasets diferentes:  ['dino' 'away' 'h_lines' 'v_lines' 'x_shape' 'star' 'high_lines' 'dots'
#  'circle' 'bullseye' 'slant_up' 'slant_down' 'wide_lines']

# %%
metrics = []

for ds in data['dataset'].unique():
    subset = data[data['dataset'] == ds]
    mean_x = round(subset['x'].mean(), 3)
    mean_y = round(subset['y'].mean(), 3)
    var_x = round(subset['x'].var(), 2)
    var_y = round(subset['y'].var(), 2)
    corr = round(subset[['x', 'y']].corr().loc['x', 'y'], 3)
    metrics.append({'Dataset': ds, 'Mean X': mean_x, 'Mean Y': mean_y, 'Variance X': var_x, 'Variance Y': var_y, 'Correlation': corr})

metrics_df = pd.DataFrame(metrics)
display(HTML('<h3>Métricas Principales por Dataset</h3>'))
display(metrics_df)
# Out:
# <h3>Métricas Principales por Dataset</h3>
#        Dataset  Mean X  Mean Y  Variance X  Variance Y  Correlation
# 0         dino  54.263  47.832      281.07      725.52       -0.064
# 1         away  54.266  47.835      281.23      725.75       -0.064
# 2      h_lines  54.261  47.830      281.10      725.76       -0.062
# 3      v_lines  54.270  47.837      281.23      725.64       -0.069
# 4      x_shape  54.260  47.840      281.23      725.22       -0.066
# 5         star  54.267  47.840      281.20      725.24       -0.063
# 6   high_lines  54.269  47.835      281.12      725.76       -0.069
# 7         dots  54.260  47.840      281.16      725.24       -0.060
# 8       circle  54.267  47.838      280.90      725.23       -0.068
# 9     bullseye  54.269  47.831      281.21      725.53       -0.069
# 10    slant_up  54.266  47.831      281.19      725.69       -0.069
# 11  slant_down  54.268  47.836      281.12      725.55       -0.069
# 12  wide_lines  54.267  47.832      281.23      725.65       -0.067

# %%
fig = px.scatter(data, x='x', y='y', color='dataset', facet_col='dataset', facet_col_wrap=5, title='Datasaurus Dozen')
fig.update_layout(height=1000, width=1500)
fig.show()
